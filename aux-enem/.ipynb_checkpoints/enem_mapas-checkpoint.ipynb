# %%
## Bibliotecas para tratamento de dados, plotting e leitura de arquivos de dados
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

## Geopandas: Utilizamos para conseguir ler arquivos do tipo Shape (.shp)
import geopandas as gpd
import geoplot as gplt
import geoplot.crs as gcrs
import mapclassify as mc
# from functions import *

# %%
def percentagem(t, x):
    return (x / t) * 100 if t > 0 else 0  # Evita divisão por zero

anos = [19, 20, 21, 22]  # Lista de anos (2019-2022)
vet = np.zeros((2, len(anos)))

# Dicionário para converter valores textuais em códigos numéricos
mapeamento_presenca = {
    "Presente": 0,
    "Faltou à prova": 1,
    "Eliminado": 2
}

for i, ano in enumerate(anos):
    caminho = f"E:/dataset/enem/microdados_enem_20{ano}/DADOS/dados_enem_20{ano}.csv"
    
    # Lendo apenas as colunas necessárias
    colunas = ['NU_ANO', 'TP_PRESENCA_CN', 'TP_PRESENCA_MT', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC']
    dat = pd.read_csv(caminho, sep=';', usecols=colunas)

    # Converte colunas de presença de texto para números
    for col in ['TP_PRESENCA_CN', 'TP_PRESENCA_MT', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC']:
        dat[col] = dat[col].map(mapeamento_presenca).fillna(0).astype(int)

    total = len(dat)  # Conta o total de inscritos

    # Contagem de faltosos por dia de prova (1 = faltou)
    primeiro = ((dat['TP_PRESENCA_CH'] == 1) | (dat['TP_PRESENCA_LC'] == 1)).sum()
    segundo = ((dat['TP_PRESENCA_CN'] == 1) | (dat['TP_PRESENCA_MT'] == 1)).sum()

    vet[0, i] = percentagem(total, primeiro)
    vet[1, i] = percentagem(total, segundo)

    del dat  # Libera memória após o uso

print(vet)  # Exibe a matriz final
# Out:
# [[22.92470655 52.30041488 29.71819842 28.1343918 ]
#  [27.14185648 55.06109257 33.70488567 32.19502863]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Simulação de dados (substituir por vet reais)
vet = np.array([[25.3, 30.1, 28.4, 27.6],  # Primeiro dia
                [27.1, 32.5, 30.8, 29.9]]) # Segundo dia

# Labels dos anos
labels = ['2019', '2020', '2021', '2022']
x = np.arange(len(labels))  # Posições das barras no eixo Y
width = 0.45  # Largura das barras (um pouco mais largas)

# Configurar estilo do Seaborn
sns.set_theme(style="whitegrid", font="serif")

# Criar a figura e os eixos
fig, ax = plt.subplots(figsize=(14, 8))  # Aumentando tamanho da figura

# Criar barras horizontais usando apenas a paleta "Blues"
cores = sns.color_palette("Blues", 6)  # Extraindo tons de azul

ax.barh(x - width/2, vet[0, :], height=width, label='Primeiro Dia', color=cores[3], alpha=0.85, edgecolor='black')
ax.barh(x + width/2, vet[1, :], height=width, label='Segundo Dia', color=cores[5], alpha=0.85, edgecolor='black')

# Configuração dos rótulos
ax.set_xlabel('Percentual de Abstenção (%)', fontsize=16, fontweight='bold')
ax.set_ylabel('Edição do ENEM', fontsize=16, fontweight='bold')
ax.set_yticks(x)
ax.set_yticklabels(labels, fontsize=18)
# ax.set_title('Taxa de Abstenção no ENEM por Ano', fontsize=18, fontweight='bold')

# Adicionando rótulos nas barras
for i, v in enumerate(vet[0, :]):
    ax.text(v + 0.5, i - width/2, f'{v:.1f}%', color='black', va='center', fontsize=14)

for i, v in enumerate(vet[1, :]):
    ax.text(v + 0.5, i + width/2, f'{v:.1f}%', color='black', va='center', fontsize=14)

# Adicionando legenda fora do gráfico
ax.legend(fontsize=14, loc='upper left', bbox_to_anchor=(1, 1))

# Melhor ajuste do layout
fig.tight_layout()

# Salvando o gráfico e exibindo
plt.savefig("abstencao_enem_seaborn_blue.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
co_uf = np.array([11, 12, 13, 14, 15, 16, 17, 21, 22, 23, 24, 25, 26, 27, 28, 29, 31, 32, 33, 35, 41, 42, 43, 50, 51, 52, 53])
vet = np.zeros((len(co_uf), 9))  # Estrutura para armazenar resultados
vet[:, 0] = co_uf  # A primeira coluna armazena os códigos UF

for i, ano in enumerate(anos):
    
    print(f"Processando dados do ENEM 20{ano}...")
    caminho = f"E:/dataset/enem/microdados_enem_20{ano}/DADOS/dados_enem_20{ano}.csv"

    # Leitura otimizada do CSV
    colunas = ['CO_UF_ESC', 'TP_PRESENCA_CN', 'TP_PRESENCA_MT', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC']
    dat = pd.read_csv(caminho, sep=';', usecols=colunas)

    # Convertendo presença para valores numéricos
    for col in ['TP_PRESENCA_CN', 'TP_PRESENCA_MT', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC']:
        dat[col] = dat[col].map(mapeamento_presenca).fillna(0).astype(int)

    for j, uf in enumerate(co_uf):
        total = (dat['CO_UF_ESC'] == uf).sum()  # Contagem total de estudantes do estado

        primeiro = ((dat['CO_UF_ESC'] == uf) & ((dat['TP_PRESENCA_CH'] == 1) | (dat['TP_PRESENCA_LC'] == 1))).sum()
        segundo = ((dat['CO_UF_ESC'] == uf) & ((dat['TP_PRESENCA_CN'] == 1) | (dat['TP_PRESENCA_MT'] == 1))).sum()

        vet[j, i+1] = percentagem(total, primeiro)  # Primeiro dia na posição i+1
        vet[j, i+4] = percentagem(total, segundo)  # Segundo dia na posição i+4

    del dat  # Libera memória após a iteração

print("Processamento concluído!")
# Out:
# Processando dados do ENEM 2019...
# Processando dados do ENEM 2020...
# Processando dados do ENEM 2021...
# Processando dados do ENEM 2022...
# Processamento concluído!

# %%
# Criando DataFrame com nomes de colunas mais organizados
colunas = [
    'CD_UF', 
    'First day - ENEM 2019', 'First day - ENEM 2020', 'First day - ENEM 2021', 'First day - ENEM 2022',
    'Second day - ENEM 2019', 'Second day - ENEM 2020', 'Second day - ENEM 2021', 'Second day - ENEM 2022'
]

df = pd.DataFrame(data=vet, columns=colunas)

# Convertendo a coluna 'CD_UF' para inteiro sem risco de erro
df['CD_UF'] = df['CD_UF'].map(int)

# Salvando o DataFrame em CSV com separação por vírgula e garantindo precisão nos números
df.to_csv('mapas/abstencao.csv', sep=',', index=False, float_format='%.2f')

print("Arquivo 'abstencao.csv' salvo com sucesso!")
# Out:
# Arquivo 'abstencao.csv' salvo com sucesso!

# %% [markdown]
# ### Figura Abstenção por estados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carregar os dados de abstenção por estado
df = pd.read_csv('mapas/abstencao.csv')

# Dicionário mapeando códigos para nomes completos dos estados
estados = {
    11: 'Rondônia', 12: 'Acre', 13: 'Amazonas', 14: 'Roraima', 15: 'Pará', 16: 'Amapá', 17: 'Tocantins',
    21: 'Maranhão', 22: 'Piauí', 23: 'Ceará', 24: 'Rio Grande do Norte', 25: 'Paraíba', 26: 'Pernambuco', 
    27: 'Alagoas', 28: 'Sergipe', 29: 'Bahia', 31: 'Minas Gerais', 32: 'Espírito Santo', 33: 'Rio de Janeiro', 
    35: 'São Paulo', 41: 'Paraná', 42: 'Santa Catarina', 43: 'Rio Grande do Sul', 50: 'Mato Grosso do Sul', 
    51: 'Mato Grosso', 52: 'Goiás', 53: 'Distrito Federal'
}

# Substituir os códigos pelos nomes completos dos estados
df['Estado'] = df['CD_UF'].map(estados)

# Definir os anos analisados
anos = ['2019', '2020', '2021', '2022']

# Criar DataFrame no formato longo (melhor para Seaborn)
df_long = pd.melt(df, id_vars=['Estado'], 
                  value_vars=[f'Second day - ENEM {ano}' for ano in anos], 
                  var_name='Ano', value_name='Taxa de Abstenção')

# Ajustar nomes dos anos na coluna
df_long['Ano'] = df_long['Ano'].str.extract(r'(\d{4})')  # Extrai apenas o ano

# Configurar o estilo do Seaborn
sns.set_theme(style="whitegrid", font="serif")

# Criar a figura maior
plt.figure(figsize=(24, 14))

# Criar gráfico de barras com Seaborn
ax = sns.barplot(data=df_long, x='Estado', y='Taxa de Abstenção', hue='Ano', palette="Blues", width=0.9, edgecolor='black')

# Ajustar elementos do gráfico
plt.xlabel('Estados', fontsize=24)
plt.ylabel('Taxa de Abstenção (%)', fontsize=24)
plt.xticks(rotation=90, ha='right', fontsize=24)
plt.yticks(fontsize=22)

# Legenda fora do gráfico
plt.legend(title='Edição de ENEM', fontsize=24, title_fontsize=24, loc='upper left', bbox_to_anchor=(1.05, 1))

# Salvar e mostrar o gráfico com resolução 300 dpi
plt.tight_layout()
plt.savefig('abstencao_estados_enem.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # MesoRegiões

# %%
pr = list()
se = list()
prTotal = list()
seTotal = list()
pr_aux = list()
se_aux = list()
pr_auxTotal = list()
se_auxTotal = list()

aux = pd.read_csv('mapas/MesoRegião.csv')
aux.set_index('CO_MUNICIPIO_ESC', inplace=True)

for i in range(len(ano)):
    dat = pd.read_csv('E:dataset/enem/microdados_enem_20{}/DADOS/dados_enem_20{}.csv'.format(ano[i], ano[i]), sep=';')
    #__________________________________________________________________________________________________________________________________________________________
    # Quantidade de falstoso
    pr.append(dat[(dat['CO_UF_ESC'] == 15)
                  & ((dat['TP_PRESENCA_CH'] == 'Faltou à prova') | (dat['TP_PRESENCA_LC'] == 'Faltou à prova'))][['CO_MUNICIPIO_ESC', 'TP_PRESENCA_LC']])
    se.append(dat[(dat['CO_UF_ESC'] == 15)
                  & ((dat['TP_PRESENCA_CN'] == 'Faltou à prova') | (dat['TP_PRESENCA_MT'] == 'Faltou à prova'))][['CO_MUNICIPIO_ESC', 'TP_PRESENCA_MT']])

    # Quantidade de inscritos
    prTotal.append(dat[(dat['CO_UF_ESC'] == 15)][['CO_MUNICIPIO_ESC', 'TP_PRESENCA_LC']])
    seTotal.append(dat[(dat['CO_UF_ESC'] == 15)][['CO_MUNICIPIO_ESC', 'TP_PRESENCA_MT']])

    #__________________________________________________________________________________________________________________________________________________________
    # Agrupamento de faltosos
    pr_aux.append(pr[i].groupby(by='CO_MUNICIPIO_ESC').count()) # quantidade de atributos codigo municipio
    se_aux.append(se[i].groupby(by='CO_MUNICIPIO_ESC').count())

    # Agrupamento de inscritos
    pr_auxTotal.append(prTotal[i].groupby(by='CO_MUNICIPIO_ESC').count()) # quantidade de atributos codigo municipio
    se_auxTotal.append(seTotal[i].groupby(by='CO_MUNICIPIO_ESC').count())

    #__________________________________________________________________________________________________________________________________________________________
    # Join de codigo municipio faltosos
    pr_aux[i] = pd.concat([pr_aux[i], aux], axis=1) # Juntar por codigo municipio
    se_aux[i] = pd.concat([se_aux[i], aux], axis=1)

    # Join de codigo municipio inscritos
    pr_auxTotal[i] = pd.concat([pr_auxTotal[i], aux], axis=1) # Juntar por codigo municipio
    se_auxTotal[i] = pd.concat([se_auxTotal[i], aux], axis=1)

    #__________________________________________________________________________________________________________________________________________________________
    # Join de codigo mesorregião faltosos
    pr_aux[i] = (pr_aux[i].groupby(by='CD_MESO').sum()) # quantidade de atributos por mesorregião
    se_aux[i] = (se_aux[i].groupby(by='CD_MESO').sum())

    pr_auxTotal[i] = (pr_auxTotal[i].groupby(by='CD_MESO').sum()) # quantidade de atributos por mesorregião
    se_auxTotal[i] = (se_auxTotal[i].groupby(by='CD_MESO').sum())

    #__________________________________________________________________________________________________________________________________________________________
    # Percentual de faltosos
    pr_aux[i]['First day of the 20{} exam'.format(ano[i])] = percentagem(pr_auxTotal[i]['TP_PRESENCA_LC'], pr_aux[i]['TP_PRESENCA_LC'])
    se_aux[i]['Second day of the 20{} exam'.format(ano[i])] = percentagem(se_auxTotal[i]['TP_PRESENCA_MT'], se_aux[i]['TP_PRESENCA_MT'])

    del pr_aux[i]['TP_PRESENCA_LC'], se_aux[i]['TP_PRESENCA_MT']

    dat = pd.DataFrame()

    print('Ano 20{}'.format(ano[i]))

df = pd.concat([pr_aux[0], se_aux[0], pr_aux[1], se_aux[1], pr_aux[2], se_aux[2],  pr_aux[3], se_aux[3]], axis=1)
df.to_csv('mapas/mesoregiao_pa_2.csv', sep=',')

# %% [markdown]
# ## Tratamento de shp

# %%
mapa_estados = gpd.read_file('mapas/BR_UF_2021.zip') # Ler arquivo
mapa_para = gpd.read_file('mapas/PA_Mesorregioes_2021.zip') # Ler arquivo

dat = pd.read_csv('mapas/abstancao.csv')
dat['CD_UF'] = dat['CD_UF'].astype(str) # convert int in str

# %%
mapa_para['NM_MESO'] = ['Lower Amazon',
                        'Marajó',
                        'MA',
                        'Northeastern',
                        'Southwest',
                        'Southeast']

# %%
mapa_uf_2019 = mapa_estados.merge(# Função para juntar geopandas
    dat.groupby(['CD_UF'])[['First day of the 2019 exam', 'Second day of the 2019 exam']]
    .mean()
    .reset_index()
)

mapa_uf_2020 = mapa_estados.merge(# Função para juntar geopandas
    dat.groupby(['CD_UF'])[['First day of the 2020 exam', 'Second day of the 2020 exam']]
    .mean()
    .reset_index()
)

mapa_uf_2021 = mapa_estados.merge(# Função para juntar geopandas
    dat.groupby(['CD_UF'])[['First day of the 2021 exam', 'Second day of the 2021 exam']]
    .mean()
    .reset_index()
)

mapa_uf_2022 = mapa_estados.merge(# Função para juntar geopandas
    dat.groupby(['CD_UF'])[['First day of the 2022 exam', 'Second day of the 2022 exam']]
    .mean()
    .reset_index()
)

# %%
mapa_uf_2019.to_excel('mapas/mapa_2019.xlsx', sheet_name='data', index=False)
mapa_uf_2020.to_excel('mapas/mapa_2020.xlsx', sheet_name='data', index=False)
mapa_uf_2021.to_excel('mapas/mapa_2021.xlsx', sheet_name='data', index=False)
mapa_uf_2022.to_excel('mapas/mapa_2022.xlsx', sheet_name='data', index=False)

# %% [markdown]
# # Mesoregiões do Pará.

# %%
dat = pd.read_csv('mapas/mesoregiao_pa_2.csv')
dat['CD_MESO'] = dat['CD_MESO'].astype(str)

# %%
mapa_meso_2019 = mapa_para.merge(# Função para juntar geopandas
    dat.groupby(['CD_MESO'])[['First day of the 2019 exam', 'Second day of the 2019 exam']]
    .mean()
    .reset_index()
)

mapa_meso_2020 = mapa_para.merge(# Função para juntar geopandas
    dat.groupby(['CD_MESO'])[['First day of the 2020 exam', 'Second day of the 2020 exam']]
    .mean()
    .reset_index()
)

mapa_meso_2021 = mapa_para.merge(# Função para juntar geopandas
    dat.groupby(['CD_MESO'])[['First day of the 2021 exam', 'Second day of the 2021 exam']]
    .mean()
    .reset_index()
)

mapa_meso_2022 = mapa_para.merge(# Função para juntar geopandas
    dat.groupby(['CD_MESO'])[['First day of the 2022 exam', 'Second day of the 2022 exam']]
    .mean()
    .reset_index()
)

# %%
fig, ax = plt.subplots(figsize=(20, 10), )
scheme = mc.Quantiles([5, 10, 20, 30, 40], k=5)
gplt.choropleth(mapa_meso_2019,
                hue='Second day of the 2019 exam',
                cmap='Blues',
                legend=True,
                scheme=scheme,
                legend_kwargs={'fontsize':'16',
                               'bbox_to_anchor': (1, 0.35),
                               'frameon': False},
                ax=ax)

mapa_meso_2019.apply(lambda x: ax.annotate(text=x['NM_MESO'], fontsize=16,
                                           xy=x.geometry.centroid.coords[0],
                                           ha='center'), axis=1)

# %%
fig, ax = plt.subplots(figsize=(20, 10))
scheme = mc.Quantiles([5, 10, 20, 30, 40], k=5)
gplt.choropleth(mapa_meso_2020,
                hue='Second day of the 2020 exam',
                cmap='Greens',
                legend=True,
                scheme=scheme,
                legend_kwargs={'fontsize':'16',
                               'bbox_to_anchor': (1, 0.35),
                               'frameon': False},
                ax=ax)

mapa_meso_2020.apply(lambda x: ax.annotate(text=x['NM_MESO'], fontsize=16,
                                           xy=x.geometry.centroid.coords[0],
                                           ha='center'), axis=1)

# %%
fig, ax = plt.subplots(figsize=(20, 10))
scheme = mc.Quantiles([5, 10, 20, 30, 40], k=5)
gplt.choropleth(mapa_meso_2021,
                hue='Second day of the 2021 exam',
                cmap='Greens',
                legend=True,
                scheme=scheme,
                legend_kwargs={'fontsize':'16',
                               'bbox_to_anchor': (1, 0.35),
                               'frameon': False},
                ax=ax)

mapa_meso_2021.apply(lambda x: ax.annotate(text=x['NM_MESO'], fontsize=16,
                                           xy=x.geometry.centroid.coords[0],
                                           ha='center'), axis=1)

# %%
fig, ax = plt.subplots(figsize=(20, 10))
scheme = mc.Quantiles([5, 10, 20, 30, 40], k=5)
gplt.choropleth(mapa_meso_2022,
                hue='Second day of the 2022 exam',
                cmap='Greens',
                legend=True,
                scheme=scheme,
                legend_kwargs={'fontsize':'16',
                               'bbox_to_anchor': (1, 0.35),
                               'frameon': False},
                ax=ax)

mapa_meso_2022.apply(lambda x: ax.annotate(text=x['NM_MESO'], fontsize=16,
                                           xy=x.geometry.centroid.coords[0],
                                           ha='center'), axis=1)

# %%
fig, axes = plt.subplots(1, 4, figsize=(24, 6))

# Configurações do esquema de cores e classes
scheme_2019 = mc.Quantiles([5, 10, 20, 30, 40], k=5)
scheme_2020 = mc.Quantiles([5, 10, 20, 30, 40], k=5)
scheme_2021 = mc.Quantiles([5, 10, 20, 30, 40], k=5)
scheme_2022 = mc.Quantiles([5, 10, 20, 30, 40], k=5)

# Função para adicionar a bússola
def add_compass(ax, x=0.1, y=0.9):
    ax.annotate('N', xy=(x, y), xytext=(x, y-0.1),
                arrowprops=dict(facecolor='black', width=5, headwidth=15),
                ha='center', va='center', fontsize=12, xycoords=ax.transAxes)

# Mapa de 2019
gplt.choropleth(mapa_meso_2019, hue='Second day of the 2019 exam', cmap='Blues', legend=True,
                scheme=scheme_2019, legend_kwargs={'fontsize': '14', 'bbox_to_anchor': (1, 0.35),
                'frameon': False}, ax=axes[0])
axes[0].set_title("2019", fontsize=16)
mapa_meso_2019.apply(lambda x: axes[0].annotate(text=x['NM_MESO'], fontsize=8,
                            xy=x.geometry.centroid.coords[0], ha='center'), axis=1)
add_compass(axes[0])

# Mapa de 2020
gplt.choropleth(mapa_meso_2020, hue='Second day of the 2020 exam', cmap='Greens', legend=True,
                scheme=scheme_2020, legend_kwargs={'fontsize': '14', 'bbox_to_anchor': (1, 0.35),
                'frameon': False}, ax=axes[1])
axes[1].set_title("2020", fontsize=16)
mapa_meso_2020.apply(lambda x: axes[1].annotate(text=x['NM_MESO'], fontsize=8,
                            xy=x.geometry.centroid.coords[0], ha='center'), axis=1)
add_compass(axes[1])

# Mapa de 2021
gplt.choropleth(mapa_meso_2021, hue='Second day of the 2021 exam', cmap='Purples', legend=True,
                scheme=scheme_2021, legend_kwargs={'fontsize': '14', 'bbox_to_anchor': (1, 0.35),
                'frameon': False}, ax=axes[2])
axes[2].set_title("2021", fontsize=16)
mapa_meso_2021.apply(lambda x: axes[2].annotate(text=x['NM_MESO'], fontsize=8,
                            xy=x.geometry.centroid.coords[0], ha='center'), axis=1)
add_compass(axes[2])

# Mapa de 2022
gplt.choropleth(mapa_meso_2022, hue='Second day of the 2022 exam', cmap='Oranges', legend=True,
                scheme=scheme_2022, legend_kwargs={'fontsize': '14', 'bbox_to_anchor': (1, 0.35),
                'frameon': False}, ax=axes[3])
axes[3].set_title("2022", fontsize=16)
mapa_meso_2022.apply(lambda x: axes[3].annotate(text=x['NM_MESO'], fontsize=8,
                            xy=x.geometry.centroid.coords[0], ha='center'), axis=1)
add_compass(axes[3])

# Ajuste final
plt.tight_layout()
plt.show()
